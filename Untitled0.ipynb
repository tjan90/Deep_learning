# %%
# !wget http://www.stickpng.com/assets/images/580b57fbd9996e24bc43bd50.png
# Out:
# --2018-10-26 09:30:06--  http://www.stickpng.com/assets/images/580b57fbd9996e24bc43bd50.png
# Resolving www.stickpng.com (www.stickpng.com)... 34.246.205.181, 18.203.50.47, 34.250.193.195, ...
# Connecting to www.stickpng.com (www.stickpng.com)|34.246.205.181|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 193579 (189K) [image/png]
# Saving to: ‘580b57fbd9996e24bc43bd50.png’
#
# 580b57fbd9996e24bc4 100%[===================>] 189.04K   238KB/s    in 0.8s
#
# 2018-10-26 09:30:07 (238 KB/s) - ‘580b57fbd9996e24bc43bd50.png’ saved [193579/193579]

# %%
from skimage import io
import matplotlib.pyplot as plt
from IPython.display import Image
import urllib.request
import numpy as np

#img = Image(filename='580b57fbd9996e24bc43bd50.png')
#f = urllib.request.urlopen('http://www.stickpng.com/assets/images/580b57fbd9996e24bc43bd50.png')
#a = plt.imread(f)
#plt.imshow(a)
#plt.show(a)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#!ls "/content/drive/My Drive"

# %%
a = plt.imread("/content/drive/My Drive/passport.png")

# %%
plt.imshow(a)
